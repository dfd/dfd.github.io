# %% [markdown]
# #### Testing Jupyter Notebook Conversion

# %% [markdown]
# Testing LaTeX
# $$
# y_i = X_i \beta + \epsilon_i
# $$

# %% [markdown]
# Testing a plot

# %%
import numpy as np
import pandas as pd
x = np.random.normal(0, 10, size=10)
pd.DataFrame(
    {
        'x': x,
        'y': x * 2 + np.random.normal(0, 1, size=10)
    }
).plot.scatter(x='x', y='y');
